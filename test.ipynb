# %%
import cv2

# %%
image = cv2.imread("test.jpg")
sift = (cv2.SIFT_create())

keypoints_1, des1 = sift.detectAndCompute(image, None)
print(keypoints_1)
print(type(keypoints_1))
# Out:
# (<KeyPoint 000001E9BB2F5320>, <KeyPoint 000001E9B9A3DE90>, <KeyPoint 000001E9B9A3D980>, <KeyPoint 000001E9B9A3E1F0>, <KeyPoint 000001E9B9A3DEC0>, <KeyPoint 000001E9B9A3E700>, <KeyPoint 000001E9B9A3E370>, <KeyPoint 000001E9B9A3E1C0>, <KeyPoint 000001E9B9AF2580>, <KeyPoint 000001E9B9AF1AA0>, <KeyPoint 000001E9B9AF1AD0>, <KeyPoint 000001E9B9AF1B00>, <KeyPoint 000001E9B9AF1B30>, <KeyPoint 000001E9B9AF2340>, <KeyPoint 000001E9B9AF2370>, <KeyPoint 000001E9B9AF23A0>, <KeyPoint 000001E9B9AF23D0>, <KeyPoint 000001E9B9AF24C0>, <KeyPoint 000001E9B9AF1F80>, <KeyPoint 000001E9B9AF1F50>, <KeyPoint 000001E9B9AF1F20>, <KeyPoint 000001E9B9AF1EF0>, <KeyPoint 000001E9B9AF1EC0>, <KeyPoint 000001E9B9AF1E90>, <KeyPoint 000001E9B9AF1E60>, <KeyPoint 000001E9B9AF1E30>, <KeyPoint 000001E9B9AF1E00>, <KeyPoint 000001E9B9AF1CE0>, <KeyPoint 000001E9B9AF1CB0>, <KeyPoint 000001E9B9AF1C80>, <KeyPoint 000001E9B9AF1C50>, <KeyPoint 000001E9B9AF1C20>, <KeyPoint 000001E9B9AF1BF0>, <KeyPoint 000001E9B9AF1BC0>, <KeyPoint 0
# ...

# %%
print(des1)
print(type(des1))
# Out:
# <class 'numpy.ndarray'>
